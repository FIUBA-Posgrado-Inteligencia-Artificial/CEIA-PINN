# %%
# !pip install pyDOE
# Out:
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pyDOE) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyDOE) (1.16.0)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18170 sha256=8bae5578d3640ac8777cb42f9571145b944ef53feb9de7bfecafbaf3e5c9ba05
#   Stored in directory: /root/.cache/pip/wheels/84/20/8c/8bd43ba42b0b6d39ace1219d6da1576e0dac81b12265c4762e
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
from torch.utils.data import Dataset, DataLoader, ConcatDataset, TensorDataset

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import axes3d
from mpl_toolkits.axes_grid1 import make_axes_locatable
from pyDOE import lhs

from IPython.display import clear_output
import time
from datetime import datetime, timedelta
import gc

np.random.seed(123)
torch.random.manual_seed(123)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
 # Neural Network
class PINN_Module(nn.Module):

    def __init__(self, model_parameters):
        super(PINN_Module, self).__init__()
        self.Device = model_parameters["Device"]
        self.LowerBounds = model_parameters["LowerBounds"]
        self.UpperBounds = model_parameters["UpperBounds"]
        self.ThermalDiffusivity = model_parameters["ThermalDiffusivity"]
        self.InputDimensions = model_parameters["InputDimensions"]
        self.OutputDimensions = model_parameters["OutputDimensions"]
        self.NumberOfNeurons = model_parameters["NumberOfNeurons"]
        self.NumberOfHiddenLayers = model_parameters["NumberOfHiddenLayers"]
        self.ActivationFunction = model_parameters["ActivationFunction"]
        self.InputLayer = nn.Linear(self.InputDimensions, self.NumberOfNeurons)
        self.HiddenLayers = nn.ModuleList(
            [nn.Linear(self.NumberOfNeurons, self.NumberOfNeurons) for _ in range(self.NumberOfHiddenLayers - 1)])
        self.OutputLayer = nn.Linear(self.NumberOfNeurons, self.OutputDimensions)

        self.init_xavier()


    def forward(self, x):
        lb = self.LowerBounds
        ub = self.UpperBounds
        x = 2*(x - lb)/(ub - lb) - 1
        output = self.ActivationFunction(self.InputLayer(x))
        for k, l in enumerate(self.HiddenLayers):
            output = self.ActivationFunction(l(output))
        output = self.OutputLayer(output)
        return output


    def init_xavier(self):

        def init_weights(m):
            if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
                g = nn.init.calculate_gain('tanh')
                torch.nn.init.xavier_uniform_(m.weight, gain=g)
                # torch.nn.init.xavier_normal_(m.weight, gain=g)
                m.bias.data.fill_(0)

        self.apply(init_weights)


    def internalEnergyBalanceResidue(self, X, T):

        alpha = self.ThermalDiffusivity

        # Compute the derivatives of the output w.r.t. the inputs (space and time) using AD mechanism:
        diff_T = torch.autograd.grad(T, X, create_graph=True, grad_outputs=torch.ones_like(T))[0]
        Tx, Tt = diff_T[:, 0:1], diff_T[:, 1:2]

        # Compute the second derivative of the output w.r.t. the inputs (only space) using AD mechanism:
        Txx = torch.autograd.grad(Tx, X, create_graph=True, grad_outputs=torch.ones_like(T))[0][:, 0:1]

        residue = Tt - alpha*Txx
        return residue

# %% [markdown]
# ## Problem data

# %%
# Properties of pure solid aluminium
k = 210.0 # W/(m K)
C = 900.0 # J/(kg K)
rho = 2700.0 #kg/m^3
alpha_true = k/(rho*C)

# Boundaries of space and time domains
ti, tf = 0, 1000.0 # s
xi, xf = 0, 1.0 # m

# Non-dimensionalization
nd = True
if nd:
    tf *= alpha_true
    alpha_nd = 1

lb = torch.tensor([xi, ti])
ub = torch.tensor([xf, tf])

# Initial and boundary temperatures
T_ref = 100 #100.
bc_value = bc_value_l = bc_value_r = 300.0/T_ref # K
k1 = np.pi/xf
T_ampl = 100.0/T_ref # K
T0 = lambda x: T_ampl*torch.sin(k1*x) + bc_value # K

# %% [markdown]
# ## Exact solution

# %%
# Exact solution
T_exact = lambda x, t: T_ampl*np.sin(k1*x)*np.exp(-k1**2*alpha_nd*t) + bc_value

# Grid for evaluation the exact solution
x_test = np.linspace(xi, xf, 1000)
t_test = np.linspace(ti, tf, 1000)
ms_x, ms_t = np.meshgrid(x_test, t_test)
x_test = np.ravel(ms_x).reshape(-1, 1)
t_test = np.ravel(ms_t).reshape(-1, 1)

T_ex_grid = T_ref * T_exact(x_test, t_test).reshape(ms_x.shape)

# %%
# Plot the exact temperature distribution
fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111, projection = '3d')
#ax.view_init(elev=20, azim=-90)
surf1 = ax.plot_surface(ms_t/alpha_true, ms_x, T_ex_grid, cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf1, shrink=0.5, aspect=5)
plt.xlabel('t')
plt.ylabel('x')
plt.show()

# %% [markdown]
# ## Datasets (collocation points and labelled data points)

# %%
# Generate equispaced tensors for both space and time domains to pick from
x_tensor = torch.linspace(xi, xf, 10000, device=device)
t_tensor = torch.linspace(ti, tf, 10000, device=device)

# Number of collocation points
N_dom = 1000 # Number of collocation points for evaluating the residuals
N_bc = 300 # Number of collocation points for computing the boundary conditions
N_ic = 500 # Number of collocation points for computing the initial condition
N_data = 1000 # Number of labelled data points

# Train, validation and testing sets
tags = ["Domain", "BoundaryConditions", "InitialCondition"]
isData = True # Flag to indicate whether the analysis would use labelled data or not

# Initialize list of dataset objects
ds = []

# %%
## Collocation points for evaluating the residual of the governing PDE

# Generate collocation points within the domain using Latin Hypercube Sampling (LHS) strategy
X_dom = (lb + (ub - lb)*lhs(2, N_dom)).to(torch.float32).to(device)
y_dom = torch.zeros((N_dom, 1), device=device)

ds.append(TensorDataset(X_dom, y_dom))
# Out:
# /tmp/ipython-input-8-406105958.py:4: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   X_dom = (lb + (ub - lb)*lhs(2, N_dom)).to(torch.float32).to(device)

# %%
## Collocation points for evaluating the boundary and initial conditions

# Generate random collocation points for the left boundary
idx_bc = np.random.choice(t_tensor.size()[0], N_bc, replace=False)
t_bc_l = t_tensor[idx_bc].view(-1, 1)
x_bc_l = xi * torch.ones((N_bc, 1), device=device)
X_bc_l = torch.cat([x_bc_l, t_bc_l], axis=1)
y_bc_l = torch.full((N_bc, 1), bc_value_l)

# Generate random collocation points for the right boundary
idx_bc = np.random.choice(t_tensor.size()[0], N_bc, replace=False)
t_bc_r = t_tensor[idx_bc].view(-1, 1)
x_bc_r = xf * torch.ones((N_bc, 1), device=device)
X_bc_r = torch.cat([x_bc_r, t_bc_r], axis=1)
y_bc_r = torch.full((N_bc, 1), bc_value_r)

# Concatenate the collocation points of both boundaries
X_bc = torch.cat([X_bc_l, X_bc_r], axis=0)
y_bc = torch.cat([y_bc_l, y_bc_r], axis=0)
ds.append(TensorDataset(X_bc, y_bc))

# Generate collocation points for the initial condition
idx_ic = np.random.choice(x_tensor.size()[0], N_ic, replace=False)
x_ic = x_tensor[idx_ic].view(-1, 1)
t_ic = ti * torch.ones((N_ic, 1), device=device)
X_ic = torch.cat([x_ic, t_ic], axis=1)
y_ic = T0(x_ic)
ds.append(TensorDataset(X_ic, y_ic))

# %%
# Generate syntetic temperature labelled data
if isData:
    tags.append("LabelledData")
    omega = 0.01
    sensor_loc = [0.25, 0.5, 0.9]
    x_data, t_data = [], []
    for loc in sensor_loc:
        idx_data = np.random.choice(x_tensor.size()[0], N_data, replace=False)
        x_data.append(torch.full((N_data, 1), loc, device=device))
        t_data.append(t_tensor[idx_data].view(-1, 1))

    X_data = torch.cat([torch.cat(x_data, axis=0), torch.cat(t_data, axis=0)], axis=1)
    exact_temp_data = T_exact(X_data[:, 0].data.cpu().numpy(), X_data[:, 1].data.cpu().numpy())
    noisy_temp_data = exact_temp_data.reshape(-1, 1) + omega*np.max(exact_temp_data)*np.random.normal(size=(len(sensor_loc)*N_data, 1))
    y_data = torch.from_numpy(noisy_temp_data).to(torch.float32).to(device)
    ds.append(TensorDataset(X_data, y_data))

# %%
# Dictionary of dataset objects
datasets = dict(zip(tags, ds))

# %%
# Plot the locations of the collocation points in the space-time domain
X_dom_train = (datasets["Domain"][:][0]).data.cpu().numpy()
X_bc_train = (datasets["BoundaryConditions"][:][0]).data.cpu().numpy()
X_ic_train = (datasets["InitialCondition"][:][0]).data.cpu().numpy()
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X_dom_train[:, 1:2], X_dom_train[0:, 0:1], s=4, c='r', label=f'N_dom={len(X_dom_train)}')
ax.scatter(X_bc_train[:, 1:2], X_bc_train[:, 0:1], s=4, c='b', label=f'N_bc={len(X_bc_train)}')
ax.scatter(X_ic_train[:, 1:2], X_ic_train[:, 0:1], s=4, c='g', label=f'N_ic={len(X_ic_train)}')
if isData:
    X_data_train = (datasets["LabelledData"][:][0]).data.cpu().numpy()
    y_data_train = (datasets["LabelledData"][:][1]).data.cpu().numpy()
    ax.scatter(X_data_train[:, 1:2], X_data_train[:, 0:1], s=4, c='m', label=f'N_Data={len(X_data_train)}', marker='x')
ax.legend()
plt.xlabel('Time domain (t)')
plt.ylabel('Space domain (x)')
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()

# %%
if isData:
    colors = ['k', 'b', 'r', 'g']
    fig = plt.figure()
    ax = fig.add_subplot(111)
    for i, sensor in enumerate(sensor_loc):
        t_data_loc = np.linspace(ti, tf, N_data).reshape(-1, 1)
        x_data_loc = np.full((N_data, 1), sensor)
        T_ex = T_exact(x_data_loc, t_data_loc)
        ax.plot(t_data_loc, T_ex, c=colors[i], label=f'T. exact - x={sensor}')
        ax.scatter(X_data_train[N_data*i:N_data*(i+1), 1:2], y_data_train[N_data*i:N_data*(i+1)], s=4, c='m', label=f'T. noisy - x={sensor}')

    ax.legend()
    plt.xlabel('Time domain (t)')
    plt.ylabel('Temperature (T)')
    plt.title(f'Temperature at sensor location (x_s={sensor_loc})')
    plt.show()

# %% [markdown]
# ## Main execution - Implementation 1

# %%
# Input dictionary for model instance
torch.random.manual_seed(456)
alpha_inv_input = nn.Parameter(torch.rand(1)) #Make alpha a trainable parameter
tanh = nn.Tanh()
alpha_fun = lambda x: x * tanh(1e3 * x) #torch.exp(x) #x*tanh(1e3*x)
model_parameters = {
    "Device": device,
    "LowerBounds": lb.to(device),
    "UpperBounds": ub.to(device),
    "ThermalDiffusivity": alpha_fun(alpha_inv_input).to(device),
    "InputDimensions": 2,
    "OutputDimensions": 1,
    "NumberOfNeurons": 30,
    "NumberOfHiddenLayers": 4,
    "ActivationFunction": nn.Tanh()
}
print('alpha_nd: ', alpha_nd, 'alpha_inv_input: ', alpha_inv_input.item(), 'alpha_inv: ', alpha_fun(alpha_inv_input).item())
# Out:
# alpha_nd:  1 alpha_inv_input:  0.6815125346183777 alpha_inv:  0.6815125346183777

# %%
# Model construction
torch.manual_seed(10)
model = PINN_Module(model_parameters).to(device)

# %%
# Fitting stage
t0 = datetime.now()
data_time_now = datetime.now().strftime("%d%m%Y_%H%M%S")

epochs = 20000
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam([
    {'params': model.parameters(), 'lr': 1e-3}, {'params': alpha_inv_input, 'lr': 0.1}], weight_decay=1e-3)
    #list(model.parameters()) + [alpha_inv_input],
    #lr=0.001, weight_decay=1e-3)
loss_train = []
loss_train_dom = []
loss_train_bc = []
loss_train_ic = []
loss_train_data = []
alpha_values = []
train_keys = ['Overall', 'Domain', 'BC', 'IC', 'Data', 'alpha']
for epoch in range(epochs):
    loss_list = []
    optimizer.zero_grad()
    # Move alpha_inv_input to the device within the training loop
    model.ThermalDiffusivity = alpha_fun(alpha_inv_input).to(device)
    for tag in tags:
        X = (datasets[tag][:][0]).to(device)
        y = (datasets[tag][:][1]).to(device)
        if tag=='Domain':
            X.requires_grad = True
            T = model(X)
            y_hat = model.internalEnergyBalanceResidue(X, T)
            loss = loss_fn(y_hat, y)
            loss_list.append(loss)

        else:
            T = model(X)
            loss = loss_fn(T, y)
            loss_list.append(loss)

    loss = sum(loss_list)
    if loss < 1e-4:
        print('Overall loss dropped below tolerance value of 1e-4. Training stopped.')
        break
    loss.backward()
    optimizer.step()

    loss_list.insert(0, loss)
    loss_train.append(loss_list[0].item())
    loss_train_dom.append(loss_list[1].item())
    loss_train_bc.append(loss_list[2].item())
    loss_train_ic.append(loss_list[3].item())
    if isData:
        loss_train_data.append(loss_list[4].item())

    alpha_values.append(alpha_inv_input.item())
    loss_list.append(alpha_fun(alpha_inv_input).item()) #loss_list.append(alpha_inv_fun(alpha_inv_input).item())


    if epoch % 100 == 0:
        log_dict = dict(zip(train_keys, loss_list))
        aux = "".join(f"{key}: {value:.5e}, " for key, value in log_dict.items())
        optimizer_str = type(optimizer).__name__
        print(f"##TRAIN## {optimizer_str} - Epoch: {epoch}, " + aux)

elapsed_time_train = datetime.now() - t0
print("\nTraining Time: ", elapsed_time_train.seconds, "[s]")
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py:823: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:180.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ##TRAIN## Adam - Epoch: 0, Overall: 8.00638e+02, Domain: 7.57678e+02, BC: 1.09333e+01, IC: 1.85744e+01, Data: 1.34519e+01, alpha: 5.81513e-01,
# ##TRAIN## Adam - Epoch: 100, Overall: 1.93961e+01, Domain: 8.22232e-01, BC: 4.72281e+00, IC: 7.44614e+00, Data: 6.40489e+00, alpha: 3.99393e-01,
# ##TRAIN## Adam - Epoch: 200, Overall: 4.76670e+00, Domain: 4.89759e-01, BC: 8.96618e-01, IC: 1.93842e+00, Data: 1.44190e+00, alpha: 3.16385e-01,
# ##TRAIN## Adam - Epoch: 300, Overall: 6.37402e-01, Domain: 2.66103e-01, BC: 1.42941e-02, IC: 2.56345e-01, Data: 1.00660e-01, alpha: 2.77137e-01,
# ##TRAIN## Adam - Epoch: 400, Overall: 2.45135e-01, Domain: 1.38972e-01, BC: 1.17135e-02, IC: 7.83803e-02, Data: 1.60691e-02, alpha: 2.58728e-01,
# ##TRAIN## Adam - Epoch: 500, Overall: 1.81316e-01, Domain: 8.98932e-02, BC: 1.96503e-02, IC: 5.78687e-02, Data: 1.39035e-02, alpha: 2.48999e-01,
# ##TRAIN## Adam - Epoch: 600, Overall: 1.46551e-01, Domain: 6.44360e-02, BC: 1.83407e-02, IC: 5.04946e-02, Data: 1.32800e-02, alpha: 2.42992e-01,
# ##TRAIN## Adam - Epoch: 700, Overall: 1.20130e-01, Domain: 4.87150e-02, BC: 1.50153e-02, IC: 4.38225e-02, Data: 1.25775e-02, alpha: 2.39312e-01,
# ##TRAIN## Adam - Epoch: 800, Overall: 9.86487e-02, Domain: 3.81566e-02, BC: 1.13565e-02, IC: 3.70892e-02, Data: 1.20464e-02, alpha: 2.37015e-01,
# ##TRAIN## Adam - Epoch: 900, Overall: 8.12955e-02, Domain: 3.07337e-02, BC: 8.03627e-03, IC: 3.06650e-02, Data: 1.18605e-02, alpha: 2.35438e-01,
# ##TRAIN## Adam - Epoch: 1000, Overall: 6.77314e-02, Domain: 2.53133e-02, BC: 5.36587e-03, IC: 2.49760e-02, Data: 1.20763e-02, alpha: 2.34247e-01,
# ##TRAIN## Adam - Epoch: 1100, Overall: 5.75375e-02, Domain: 2.12003e-02, BC: 3.41511e-03, IC: 2.02895e-02, Data: 1.26326e-02, alpha: 2.33396e-01,
# ##TRAIN## Adam - Epoch: 1200, Overall: 5.01254e-02, Domain: 1.79738e-02, BC: 2.10142e-03, IC: 1.66614e-02, Data: 1.33887e-02, alpha: 2.33048e-01,
# ##TRAIN## Adam - Epoch: 1300, Overall: 4.48343e-02, Domain: 1.53931e-02, BC: 1.27553e-03, IC: 1.39821e-02, Data: 1.41836e-02, alpha: 2.33458e-01,
# ##TRAIN## Adam - Epoch: 1400, Overall: 4.10516e-02, Domain: 1.33186e-02, BC: 7.84164e-04, IC: 1.20619e-02, Data: 1.48870e-02, alpha: 2.34861e-01,
# ##TRAIN## Adam - Epoch: 1500, Overall: 3.82844e-02, Domain: 1.16565e-02, BC: 5.03205e-04, IC: 1.07025e-02, Data: 1.54221e-02, alpha: 2.37406e-01,
# ##TRAIN## Adam - Epoch: 1600, Overall: 3.61739e-02, Domain: 1.03281e-02, BC: 3.46323e-04, IC: 9.73649e-03, Data: 1.57630e-02, alpha: 2.41150e-01,
# ##TRAIN## Adam - Epoch: 1700, Overall: 3.44772e-02, Domain: 9.26359e-03, BC: 2.59895e-04, IC: 9.03551e-03, Data: 1.59182e-02, alpha: 2.46084e-01,
# ##TRAIN## Adam - Epoch: 1800, Overall: 3.30379e-02, Domain: 8.40204e-03, BC: 2.12973e-04, IC: 8.50910e-03, Data: 1.59138e-02, alpha: 2.52165e-01,
# ##TRAIN## Adam - Epoch: 1900, Overall: 3.17572e-02, Domain: 7.69450e-03, BC: 1.88463e-04, IC: 8.09493e-03, Data: 1.57793e-02, alpha: 2.59337e-01,
# ##TRAIN## Adam - Epoch: 2000, Overall: 4.93391e-02, Domain: 2.73691e-02, BC: 1.63203e-04, IC: 6.82524e-03, Data: 1.49815e-02, alpha: 2.67288e-01,
# ##TRAIN## Adam - Epoch: 2100, Overall: 2.94688e-02, Domain: 6.59047e-03, BC: 1.79171e-04, IC: 7.52347e-03, Data: 1.51757e-02, alpha: 2.76353e-01,
# ##TRAIN## Adam - Epoch: 2200, Overall: 2.84153e-02, Domain: 6.18069e-03, BC: 1.76895e-04, IC: 7.21664e-03, Data: 1.48411e-02, alpha: 2.86278e-01,
# ##TRAIN## Adam - Epoch: 2300, Overall: 2.74873e-02, Domain: 5.76798e-03, BC: 2.00792e-04, IC: 7.18942e-03, Data: 1.43291e-02, alpha: 2.96621e-01,
# ##TRAIN## Adam - Epoch: 2400, Overall: 2.63737e-02, Domain: 5.46890e-03, BC: 1.90557e-04, IC: 6.76225e-03, Data: 1.39519e-02, alpha: 3.07928e-01,
# ##TRAIN## Adam - Epoch: 2500, Overall: 2.53998e-02, Domain: 5.20437e-03, BC: 1.94624e-04, IC: 6.48510e-03, Data: 1.35157e-02, alpha: 3.20000e-01,
# ##TRAIN## Adam - Epoch: 2600, Overall: 2.44061e-02, Domain: 4.86310e-03, BC: 2.22724e-04, IC: 6.40069e-03, Data: 1.29196e-02, alpha: 3.32361e-01,
# ##TRAIN## Adam - Epoch: 2700, Overall: 2.34498e-02, Domain: 4.67357e-03, BC: 2.13752e-04, IC: 6.05012e-03, Data: 1.25124e-02, alpha: 3.45613e-01,
# ##TRAIN## Adam - Epoch: 2800, Overall: 2.25151e-02, Domain: 4.50149e-03, BC: 2.17477e-04, IC: 5.76905e-03, Data: 1.20271e-02, alpha: 3.59505e-01,
# ##TRAIN## Adam - Epoch: 2900, Overall: 2.15389e-02, Domain: 4.20101e-03, BC: 2.50428e-04, IC: 5.72135e-03, Data: 1.13661e-02, alpha: 3.73469e-01,
# ##TRAIN## Adam - Epoch: 3000, Overall: 2.06066e-02, Domain: 4.04730e-03, BC: 2.34356e-04, IC: 5.34332e-03, Data: 1.09816e-02, alpha: 3.88304e-01,
# ##TRAIN## Adam - Epoch: 3100, Overall: 1.97048e-02, Domain: 3.90307e-03, BC: 2.35159e-04, IC: 5.06367e-03, Data: 1.05029e-02, alpha: 4.03650e-01,
# ##TRAIN## Adam - Epoch: 3200, Overall: 1.02210e-01, Domain: 8.93863e-02, BC: 2.57061e-04, IC: 3.13247e-03, Data: 9.43415e-03, alpha: 4.20357e-01,
# ##TRAIN## Adam - Epoch: 3300, Overall: 1.78583e-02, Domain: 3.48405e-03, BC: 2.56152e-04, IC: 4.72058e-03, Data: 9.39751e-03, alpha: 4.35368e-01,
# ##TRAIN## Adam - Epoch: 3400, Overall: 1.69763e-02, Domain: 3.39484e-03, BC: 2.40462e-04, IC: 4.35888e-03, Data: 8.98215e-03, alpha: 4.51791e-01,
# ##TRAIN## Adam - Epoch: 3500, Overall: 1.61338e-02, Domain: 3.29003e-03, BC: 2.35991e-04, IC: 4.09040e-03, Data: 8.51734e-03, alpha: 4.68697e-01,
# ##TRAIN## Adam - Epoch: 3600, Overall: 2.86649e-01, Domain: 2.77821e-01, BC: 2.47675e-04, IC: 1.76078e-03, Data: 6.81886e-03, alpha: 4.86794e-01,
# ##TRAIN## Adam - Epoch: 3700, Overall: 1.44139e-02, Domain: 2.95925e-03, BC: 2.37019e-04, IC: 3.69596e-03, Data: 7.52170e-03, alpha: 5.02987e-01,
# ##TRAIN## Adam - Epoch: 3800, Overall: 1.36207e-02, Domain: 2.86775e-03, BC: 2.19590e-04, IC: 3.39815e-03, Data: 7.13526e-03, alpha: 5.20441e-01,
# ##TRAIN## Adam - Epoch: 3900, Overall: 1.28679e-02, Domain: 2.78682e-03, BC: 2.09601e-04, IC: 3.15204e-03, Data: 6.71949e-03, alpha: 5.38182e-01,
# ##TRAIN## Adam - Epoch: 4000, Overall: 1.22965e-02, Domain: 2.82852e-03, BC: 2.25901e-04, IC: 3.07160e-03, Data: 6.17046e-03, alpha: 5.55295e-01,
# ##TRAIN## Adam - Epoch: 4100, Overall: 1.13345e-02, Domain: 2.47695e-03, BC: 1.90154e-04, IC: 2.75358e-03, Data: 5.91383e-03, alpha: 5.72914e-01,
# ##TRAIN## Adam - Epoch: 4200, Overall: 1.06729e-02, Domain: 2.42581e-03, BC: 1.75149e-04, IC: 2.51212e-03, Data: 5.55980e-03, alpha: 5.90666e-01,
# ##TRAIN## Adam - Epoch: 4300, Overall: 1.10811e-02, Domain: 2.97742e-03, BC: 2.92532e-04, IC: 2.37288e-03, Data: 5.43825e-03, alpha: 6.05636e-01,
# ##TRAIN## Adam - Epoch: 4400, Overall: 9.36992e-03, Domain: 2.12451e-03, BC: 1.59816e-04, IC: 2.20821e-03, Data: 4.87739e-03, alpha: 6.24292e-01,
# ##TRAIN## Adam - Epoch: 4500, Overall: 8.79741e-03, Domain: 2.10956e-03, BC: 1.39158e-04, IC: 1.95322e-03, Data: 4.59547e-03, alpha: 6.41445e-01,
# ##TRAIN## Adam - Epoch: 4600, Overall: 8.27801e-03, Domain: 2.06914e-03, BC: 1.27853e-04, IC: 1.76706e-03, Data: 4.31397e-03, alpha: 6.58379e-01,
# ##TRAIN## Adam - Epoch: 4700, Overall: 1.02990e-02, Domain: 4.44507e-03, BC: 1.80797e-04, IC: 1.75538e-03, Data: 3.91778e-03, alpha: 6.71940e-01,
# ##TRAIN## Adam - Epoch: 4800, Overall: 7.26439e-03, Domain: 1.79493e-03, BC: 1.12101e-04, IC: 1.52121e-03, Data: 3.83615e-03, alpha: 6.87641e-01,
# ##TRAIN## Adam - Epoch: 4900, Overall: 6.84294e-03, Domain: 1.78627e-03, BC: 9.99139e-05, IC: 1.33783e-03, Data: 3.61892e-03, alpha: 7.03639e-01,
# ##TRAIN## Adam - Epoch: 5000, Overall: 6.46074e-03, Domain: 1.75753e-03, BC: 9.39072e-05, IC: 1.19963e-03, Data: 3.40967e-03, alpha: 7.19104e-01,
# ##TRAIN## Adam - Epoch: 5100, Overall: 2.38007e-01, Domain: 2.30586e-01, BC: 3.52592e-04, IC: 2.81650e-03, Data: 4.25191e-03, alpha: 7.27712e-01,
# ##TRAIN## Adam - Epoch: 5200, Overall: 5.78673e-03, Domain: 1.51713e-03, BC: 9.53979e-05, IC: 1.08544e-03, Data: 3.08877e-03, alpha: 7.42175e-01,
# ##TRAIN## Adam - Epoch: 5300, Overall: 5.45245e-03, Domain: 1.51399e-03, BC: 8.07306e-05, IC: 9.10363e-04, Data: 2.94736e-03, alpha: 7.56313e-01,
# ##TRAIN## Adam - Epoch: 5400, Overall: 5.17215e-03, Domain: 1.49336e-03, BC: 7.74789e-05, IC: 8.04139e-04, Data: 2.79717e-03, alpha: 7.70202e-01,
# ##TRAIN## Adam - Epoch: 5500, Overall: 8.92493e-03, Domain: 5.27649e-03, BC: 7.27036e-05, IC: 8.34306e-04, Data: 2.74143e-03, alpha: 7.82881e-01,
# ##TRAIN## Adam - Epoch: 5600, Overall: 4.75289e-03, Domain: 1.32916e-03, BC: 8.37716e-05, IC: 7.59166e-04, Data: 2.58079e-03, alpha: 7.89333e-01,
# ##TRAIN## Adam - Epoch: 5700, Overall: 4.47555e-03, Domain: 1.31109e-03, BC: 7.34334e-05, IC: 6.07432e-04, Data: 2.48360e-03, alpha: 8.01533e-01,
# ##TRAIN## Adam - Epoch: 5800, Overall: 4.27119e-03, Domain: 1.28845e-03, BC: 7.19625e-05, IC: 5.32613e-04, Data: 2.37816e-03, alpha: 8.13633e-01,
# ##TRAIN## Adam - Epoch: 5900, Overall: 4.35930e-03, Domain: 1.23753e-03, BC: 1.02804e-04, IC: 6.97217e-04, Data: 2.32175e-03, alpha: 8.14375e-01,
# ##TRAIN## Adam - Epoch: 6000, Overall: 3.97293e-03, Domain: 1.13104e-03, BC: 7.46444e-05, IC: 4.84545e-04, Data: 2.28269e-03, alpha: 8.24626e-01,
# ##TRAIN## Adam - Epoch: 6100, Overall: 3.80133e-03, Domain: 1.11797e-03, BC: 7.23680e-05, IC: 4.13034e-04, Data: 2.19795e-03, alpha: 8.36080e-01,
# ##TRAIN## Adam - Epoch: 6200, Overall: 3.74537e-03, Domain: 1.17144e-03, BC: 7.06170e-05, IC: 3.75615e-04, Data: 2.12769e-03, alpha: 8.46702e-01,
# ##TRAIN## Adam - Epoch: 6300, Overall: 3.69249e-03, Domain: 1.03615e-03, BC: 8.86666e-05, IC: 4.61021e-04, Data: 2.10666e-03, alpha: 8.44893e-01,
# ##TRAIN## Adam - Epoch: 6400, Overall: 3.45966e-03, Domain: 9.86072e-04, BC: 7.34562e-05, IC: 3.33494e-04, Data: 2.06663e-03, alpha: 8.54307e-01,
# ##TRAIN## Adam - Epoch: 6500, Overall: 3.33204e-03, Domain: 9.70690e-04, BC: 7.27632e-05, IC: 2.85419e-04, Data: 2.00317e-03, alpha: 8.64451e-01,
# ##TRAIN## Adam - Epoch: 6600, Overall: 1.23989e-01, Domain: 1.20984e-01, BC: 6.65374e-05, IC: 7.54847e-04, Data: 2.18299e-03, alpha: 8.68874e-01,
# ##TRAIN## Adam - Epoch: 6700, Overall: 3.34033e-03, Domain: 8.62083e-04, BC: 8.77980e-05, IC: 3.75787e-04, Data: 2.01466e-03, alpha: 8.59459e-01,
# ##TRAIN## Adam - Epoch: 6800, Overall: 3.14724e-03, Domain: 8.32468e-04, BC: 7.64186e-05, IC: 2.65840e-04, Data: 1.97251e-03, alpha: 8.69372e-01,
# ##TRAIN## Adam - Epoch: 6900, Overall: 3.03475e-03, Domain: 8.20424e-04, BC: 7.58238e-05, IC: 2.23795e-04, Data: 1.91471e-03, alpha: 8.79659e-01,
# ##TRAIN## Adam - Epoch: 7000, Overall: 3.25230e-03, Domain: 1.13434e-03, BC: 8.03152e-05, IC: 1.81403e-04, Data: 1.85625e-03, alpha: 8.88948e-01,
# ##TRAIN## Adam - Epoch: 7100, Overall: 3.08197e-03, Domain: 8.41284e-04, BC: 8.79549e-05, IC: 2.79846e-04, Data: 1.87288e-03, alpha: 8.83285e-01,
# ##TRAIN## Adam - Epoch: 7200, Overall: 2.86645e-03, Domain: 7.47370e-04, BC: 7.54076e-05, IC: 1.89214e-04, Data: 1.85446e-03, alpha: 8.90832e-01,
# ##TRAIN## Adam - Epoch: 7300, Overall: 2.78173e-03, Domain: 7.31832e-04, BC: 7.50789e-05, IC: 1.60067e-04, Data: 1.81475e-03, alpha: 8.99312e-01,
# ##TRAIN## Adam - Epoch: 7400, Overall: 3.91246e-03, Domain: 1.69222e-03, BC: 1.07446e-04, IC: 2.87923e-04, Data: 1.82487e-03, alpha: 8.90125e-01,
# ##TRAIN## Adam - Epoch: 7500, Overall: 2.73921e-03, Domain: 6.74402e-04, BC: 7.31702e-05, IC: 1.67569e-04, Data: 1.82407e-03, alpha: 8.96844e-01,
# ##TRAIN## Adam - Epoch: 7600, Overall: 2.65686e-03, Domain: 6.60639e-04, BC: 7.32331e-05, IC: 1.37536e-04, Data: 1.78546e-03, alpha: 9.05714e-01,
# ##TRAIN## Adam - Epoch: 7700, Overall: 3.01425e-03, Domain: 7.98245e-04, BC: 9.84161e-05, IC: 3.03821e-04, Data: 1.81377e-03, alpha: 8.93409e-01,
# ##TRAIN## Adam - Epoch: 7800, Overall: 2.64306e-03, Domain: 6.17396e-04, BC: 7.04875e-05, IC: 1.50785e-04, Data: 1.80439e-03, alpha: 9.00975e-01,
# ##TRAIN## Adam - Epoch: 7900, Overall: 2.55985e-03, Domain: 6.02289e-04, BC: 7.09396e-05, IC: 1.21360e-04, Data: 1.76526e-03, alpha: 9.10416e-01,
# ##TRAIN## Adam - Epoch: 8000, Overall: 4.54013e-03, Domain: 2.37186e-03, BC: 7.15245e-05, IC: 2.93080e-04, Data: 1.80366e-03, alpha: 8.99975e-01,
# ##TRAIN## Adam - Epoch: 8100, Overall: 2.51980e-03, Domain: 5.51772e-04, BC: 7.08889e-05, IC: 1.26354e-04, Data: 1.77079e-03, alpha: 9.08779e-01,
# ##TRAIN## Adam - Epoch: 8200, Overall: 5.00908e-03, Domain: 2.78656e-03, BC: 9.18314e-05, IC: 3.50881e-04, Data: 1.77981e-03, alpha: 9.07325e-01,
# ##TRAIN## Adam - Epoch: 8300, Overall: 2.47877e-03, Domain: 5.36790e-04, BC: 6.98186e-05, IC: 1.19097e-04, Data: 1.75307e-03, alpha: 9.12946e-01,
# ##TRAIN## Adam - Epoch: 8400, Overall: 2.40730e-03, Domain: 5.20439e-04, BC: 6.94152e-05, IC: 9.45394e-05, Data: 1.72291e-03, alpha: 9.21301e-01,
# ##TRAIN## Adam - Epoch: 8500, Overall: 2.78275e-03, Domain: 6.71370e-04, BC: 6.90563e-05, IC: 2.38451e-04, Data: 1.80387e-03, alpha: 8.98616e-01,
# ##TRAIN## Adam - Epoch: 8600, Overall: 2.42664e-03, Domain: 4.83221e-04, BC: 6.39583e-05, IC: 1.14477e-04, Data: 1.76499e-03, alpha: 9.09931e-01,
# ##TRAIN## Adam - Epoch: 8700, Overall: 2.35048e-03, Domain: 4.71306e-04, BC: 6.51325e-05, IC: 9.02669e-05, Data: 1.72378e-03, alpha: 9.20782e-01,
# ##TRAIN## Adam - Epoch: 8800, Overall: 3.00973e-03, Domain: 9.18074e-04, BC: 8.16855e-05, IC: 2.54900e-04, Data: 1.75507e-03, alpha: 9.11473e-01,
# ##TRAIN## Adam - Epoch: 8900, Overall: 2.36307e-03, Domain: 4.68863e-04, BC: 6.25612e-05, IC: 9.86131e-05, Data: 1.73304e-03, alpha: 9.18042e-01,
# ##TRAIN## Adam - Epoch: 9000, Overall: 1.34651e-02, Domain: 1.15491e-02, BC: 9.81870e-05, IC: 6.61058e-05, Data: 1.75173e-03, alpha: 9.27410e-01,
# ##TRAIN## Adam - Epoch: 9100, Overall: 9.61825e-02, Domain: 9.37802e-02, BC: 4.68182e-05, IC: 4.65395e-04, Data: 1.89011e-03, alpha: 9.21038e-01,
# ##TRAIN## Adam - Epoch: 9200, Overall: 2.29002e-03, Domain: 4.32389e-04, BC: 6.12774e-05, IC: 9.05885e-05, Data: 1.70577e-03, alpha: 9.24770e-01,
# ##TRAIN## Adam - Epoch: 9300, Overall: 2.56530e-01, Domain: 2.54424e-01, BC: 3.17597e-04, IC: 1.35268e-04, Data: 1.65292e-03, alpha: 9.44050e-01,
# ##TRAIN## Adam - Epoch: 9400, Overall: 2.32438e-03, Domain: 4.09356e-04, BC: 5.40843e-05, IC: 1.13063e-04, Data: 1.74788e-03, alpha: 9.12974e-01,
# ##TRAIN## Adam - Epoch: 9500, Overall: 2.22592e-03, Domain: 3.88154e-04, BC: 5.58630e-05, IC: 7.57581e-05, Data: 1.70614e-03, alpha: 9.25357e-01,
# ##TRAIN## Adam - Epoch: 9600, Overall: 6.19033e-03, Domain: 4.09419e-03, BC: 9.29960e-05, IC: 3.09593e-04, Data: 1.69355e-03, alpha: 9.18833e-01,
# ##TRAIN## Adam - Epoch: 9700, Overall: 2.23701e-03, Domain: 3.80991e-04, BC: 5.72200e-05, IC: 8.46020e-05, Data: 1.71420e-03, alpha: 9.22926e-01,
# ##TRAIN## Adam - Epoch: 9800, Overall: 2.16744e-03, Domain: 3.65110e-04, BC: 5.65419e-05, IC: 6.35660e-05, Data: 1.68223e-03, alpha: 9.32964e-01,
# ##TRAIN## Adam - Epoch: 9900, Overall: 2.47280e-03, Domain: 5.36769e-04, BC: 5.36635e-05, IC: 1.44495e-04, Data: 1.73788e-03, alpha: 9.12370e-01,
# ##TRAIN## Adam - Epoch: 10000, Overall: 2.17633e-03, Domain: 3.47389e-04, BC: 5.04894e-05, IC: 7.31501e-05, Data: 1.70530e-03, alpha: 9.25338e-01,
# ##TRAIN## Adam - Epoch: 10100, Overall: 2.12408e-03, Domain: 3.46023e-04, BC: 5.16310e-05, IC: 5.52402e-05, Data: 1.67119e-03, alpha: 9.36102e-01,
# ##TRAIN## Adam - Epoch: 10200, Overall: 2.47159e-03, Domain: 5.19476e-04, BC: 5.30323e-05, IC: 1.75453e-04, Data: 1.72363e-03, alpha: 9.15321e-01,
# ##TRAIN## Adam - Epoch: 10300, Overall: 2.17999e-03, Domain: 3.56301e-04, BC: 4.71611e-05, IC: 7.30585e-05, Data: 1.70347e-03, alpha: 9.25657e-01,
# ##TRAIN## Adam - Epoch: 10400, Overall: 2.10638e-03, Domain: 3.35269e-04, BC: 4.80462e-05, IC: 5.33104e-05, Data: 1.66975e-03, alpha: 9.36693e-01,
# ##TRAIN## Adam - Epoch: 10500, Overall: 5.07358e-03, Domain: 3.21174e-03, BC: 4.58337e-05, IC: 1.05267e-04, Data: 1.71074e-03, alpha: 9.23583e-01,
# ##TRAIN## Adam - Epoch: 10600, Overall: 3.06353e-03, Domain: 1.21770e-03, BC: 5.34980e-05, IC: 1.08107e-04, Data: 1.68423e-03, alpha: 9.26469e-01,
# ##TRAIN## Adam - Epoch: 10700, Overall: 2.37198e-03, Domain: 6.11953e-04, BC: 4.64509e-05, IC: 4.82140e-05, Data: 1.66536e-03, alpha: 9.36412e-01,
# ##TRAIN## Adam - Epoch: 10800, Overall: 2.14021e-03, Domain: 3.35551e-04, BC: 4.16586e-05, IC: 8.10314e-05, Data: 1.68197e-03, alpha: 9.30182e-01,
# ##TRAIN## Adam - Epoch: 10900, Overall: 2.04423e-03, Domain: 2.93565e-04, BC: 4.20461e-05, IC: 4.83258e-05, Data: 1.66029e-03, alpha: 9.39689e-01,
# ##TRAIN## Adam - Epoch: 11000, Overall: 2.45718e-03, Domain: 6.06163e-04, BC: 4.45310e-05, IC: 1.18458e-04, Data: 1.68803e-03, alpha: 9.25553e-01,
# ##TRAIN## Adam - Epoch: 11100, Overall: 2.04691e-03, Domain: 2.83667e-04, BC: 3.87412e-05, IC: 5.36700e-05, Data: 1.67083e-03, alpha: 9.35891e-01,
# ##TRAIN## Adam - Epoch: 11200, Overall: 1.84207e-02, Domain: 1.63555e-02, BC: 2.52557e-05, IC: 2.77333e-04, Data: 1.76257e-03, alpha: 9.15241e-01,
# ##TRAIN## Adam - Epoch: 11300, Overall: 1.48988e-02, Domain: 1.27120e-02, BC: 4.86620e-05, IC: 4.03166e-04, Data: 1.73503e-03, alpha: 9.23725e-01,
# ##TRAIN## Adam - Epoch: 11400, Overall: 2.03607e-03, Domain: 2.63663e-04, BC: 3.47077e-05, IC: 5.79275e-05, Data: 1.67977e-03, alpha: 9.32478e-01,
# ##TRAIN## Adam - Epoch: 11500, Overall: 4.63100e-03, Domain: 2.67258e-03, BC: 4.56682e-05, IC: 2.34885e-04, Data: 1.67787e-03, alpha: 9.33163e-01,
# ##TRAIN## Adam - Epoch: 11600, Overall: 2.00329e-03, Domain: 2.62603e-04, BC: 3.33872e-05, IC: 4.76243e-05, Data: 1.65967e-03, alpha: 9.39414e-01,
# ##TRAIN## Adam - Epoch: 11700, Overall: 1.19957e-01, Domain: 1.17552e-01, BC: 1.02928e-04, IC: 4.92230e-04, Data: 1.81052e-03, alpha: 9.30371e-01,
# ##TRAIN## Adam - Epoch: 11800, Overall: 2.11784e-03, Domain: 2.42331e-04, BC: 2.73941e-05, IC: 8.93425e-05, Data: 1.75877e-03, alpha: 9.09840e-01,
# ##TRAIN## Adam - Epoch: 11900, Overall: 9.58041e-03, Domain: 7.74689e-03, BC: 2.13825e-05, IC: 9.29953e-05, Data: 1.71915e-03, alpha: 9.27262e-01,
# ##TRAIN## Adam - Epoch: 12000, Overall: 2.03624e-03, Domain: 2.55821e-04, BC: 2.80000e-05, IC: 6.90527e-05, Data: 1.68336e-03, alpha: 9.30286e-01,
# ##TRAIN## Adam - Epoch: 12100, Overall: 1.96138e-03, Domain: 2.37693e-04, BC: 3.03442e-05, IC: 4.13620e-05, Data: 1.65198e-03, alpha: 9.42177e-01,
# ##TRAIN## Adam - Epoch: 12200, Overall: 2.86513e-03, Domain: 1.09271e-03, BC: 2.50043e-05, IC: 7.50278e-05, Data: 1.67238e-03, alpha: 9.35782e-01,
# ##TRAIN## Adam - Epoch: 12300, Overall: 2.43914e-03, Domain: 6.60515e-04, BC: 2.66941e-05, IC: 9.08231e-05, Data: 1.66111e-03, alpha: 9.37944e-01,
# ##TRAIN## Adam - Epoch: 12400, Overall: 1.95632e-03, Domain: 2.54211e-04, BC: 2.87887e-05, IC: 3.49391e-05, Data: 1.63839e-03, alpha: 9.47135e-01,
# ##TRAIN## Adam - Epoch: 12500, Overall: 2.06256e-03, Domain: 2.47691e-04, BC: 2.19195e-05, IC: 8.04108e-05, Data: 1.71254e-03, alpha: 9.21172e-01,
# ##TRAIN## Adam - Epoch: 12600, Overall: 4.29527e-03, Domain: 2.58505e-03, BC: 3.36852e-05, IC: 3.10504e-05, Data: 1.64548e-03, alpha: 9.40722e-01,
# ##TRAIN## Adam - Epoch: 12700, Overall: 1.97787e-03, Domain: 2.30696e-04, BC: 2.32137e-05, IC: 5.72431e-05, Data: 1.66671e-03, alpha: 9.35557e-01,
# ##TRAIN## Adam - Epoch: 12800, Overall: 1.91027e-03, Domain: 2.11147e-04, BC: 2.52875e-05, IC: 3.47438e-05, Data: 1.63910e-03, alpha: 9.47071e-01,
# ##TRAIN## Adam - Epoch: 12900, Overall: 2.53387e-03, Domain: 6.60193e-04, BC: 2.33310e-05, IC: 1.09370e-04, Data: 1.74098e-03, alpha: 9.10418e-01,
# ##TRAIN## Adam - Epoch: 13000, Overall: 2.71724e-03, Domain: 9.47945e-04, BC: 2.07458e-05, IC: 6.00868e-05, Data: 1.68846e-03, alpha: 9.31150e-01,
# ##TRAIN## Adam - Epoch: 13100, Overall: 1.98002e-03, Domain: 2.31948e-04, BC: 2.15637e-05, IC: 5.74706e-05, Data: 1.66903e-03, alpha: 9.34055e-01,
# ##TRAIN## Adam - Epoch: 13200, Overall: 2.45047e-02, Domain: 2.27789e-02, BC: 3.91365e-05, IC: 2.40356e-05, Data: 1.66267e-03, alpha: 9.45930e-01,
# ##TRAIN## Adam - Epoch: 13300, Overall: 2.74291e-03, Domain: 9.23008e-04, BC: 2.22105e-05, IC: 1.23702e-04, Data: 1.67399e-03, alpha: 9.33097e-01,
# ##TRAIN## Adam - Epoch: 13400, Overall: 1.89558e-03, Domain: 1.97576e-04, BC: 2.18570e-05, IC: 3.48940e-05, Data: 1.64125e-03, alpha: 9.45615e-01,
# ##TRAIN## Adam - Epoch: 13500, Overall: 1.94996e-03, Domain: 2.08917e-04, BC: 1.77288e-05, IC: 5.91745e-05, Data: 1.66414e-03, alpha: 9.36010e-01,
# ##TRAIN## Adam - Epoch: 13600, Overall: 1.87385e-03, Domain: 1.86844e-04, BC: 2.03645e-05, IC: 3.20554e-05, Data: 1.63459e-03, alpha: 9.48470e-01,
# ##TRAIN## Adam - Epoch: 13700, Overall: 2.00291e-03, Domain: 2.11639e-04, BC: 1.81966e-05, IC: 6.44804e-05, Data: 1.70859e-03, alpha: 9.22882e-01,
# ##TRAIN## Adam - Epoch: 13800, Overall: 2.21206e-03, Domain: 4.66262e-04, BC: 1.95943e-05, IC: 6.21326e-05, Data: 1.66407e-03, alpha: 9.34238e-01,
# ##TRAIN## Adam - Epoch: 13900, Overall: 1.01867e-02, Domain: 8.13829e-03, BC: 6.29668e-05, IC: 3.06571e-04, Data: 1.67886e-03, alpha: 9.37184e-01,
# ##TRAIN## Adam - Epoch: 14000, Overall: 2.71080e-02, Domain: 2.53860e-02, BC: 4.03052e-05, IC: 2.29201e-05, Data: 1.65878e-03, alpha: 9.43256e-01,
# ##TRAIN## Adam - Epoch: 14100, Overall: 8.90926e-02, Domain: 8.70224e-02, BC: 1.96579e-05, IC: 2.75856e-04, Data: 1.77467e-03, alpha: 9.33504e-01,
# ##TRAIN## Adam - Epoch: 14200, Overall: 2.03078e-03, Domain: 3.39478e-04, BC: 1.65495e-05, IC: 3.45038e-05, Data: 1.64025e-03, alpha: 9.46132e-01,
# ##TRAIN## Adam - Epoch: 14300, Overall: 7.79036e-03, Domain: 5.91983e-03, BC: 1.61329e-05, IC: 1.66424e-04, Data: 1.68797e-03, alpha: 9.32564e-01,
# ##TRAIN## Adam - Epoch: 14400, Overall: 6.94288e-02, Domain: 6.73549e-02, BC: 1.94756e-04, IC: 2.61149e-04, Data: 1.61801e-03, alpha: 9.50426e-01,
# ##TRAIN## Adam - Epoch: 14500, Overall: 1.88321e-03, Domain: 1.72890e-04, BC: 1.45534e-05, IC: 4.16809e-05, Data: 1.65408e-03, alpha: 9.40327e-01,
# ##TRAIN## Adam - Epoch: 14600, Overall: 1.99682e-03, Domain: 2.59951e-04, BC: 1.71111e-05, IC: 4.71701e-05, Data: 1.67259e-03, alpha: 9.32930e-01,
# ##TRAIN## Adam - Epoch: 14700, Overall: 3.05885e-03, Domain: 1.16570e-03, BC: 2.31330e-05, IC: 1.76149e-04, Data: 1.69387e-03, alpha: 9.20579e-01,
# ##TRAIN## Adam - Epoch: 14800, Overall: 1.88161e-03, Domain: 1.61803e-04, BC: 1.51674e-05, IC: 4.26742e-05, Data: 1.66197e-03, alpha: 9.37204e-01,
# ##TRAIN## Adam - Epoch: 14900, Overall: 3.15106e-03, Domain: 1.13887e-03, BC: 5.07486e-05, IC: 2.46468e-04, Data: 1.71497e-03, alpha: 9.19057e-01,
# ##TRAIN## Adam - Epoch: 15000, Overall: 1.87733e-03, Domain: 1.50648e-04, BC: 1.43342e-05, IC: 4.41869e-05, Data: 1.66816e-03, alpha: 9.35357e-01,
# ##TRAIN## Adam - Epoch: 15100, Overall: 3.00476e-03, Domain: 1.15876e-03, BC: 2.07479e-05, IC: 1.58445e-04, Data: 1.66680e-03, alpha: 9.34198e-01,
# ##TRAIN## Adam - Epoch: 15200, Overall: 1.84239e-03, Domain: 1.54817e-04, BC: 1.39255e-05, IC: 3.35480e-05, Data: 1.64010e-03, alpha: 9.45646e-01,
# ##TRAIN## Adam - Epoch: 15300, Overall: 4.81119e-03, Domain: 3.05589e-03, BC: 1.72262e-05, IC: 5.54183e-05, Data: 1.68266e-03, alpha: 9.25369e-01,
# ##TRAIN## Adam - Epoch: 15400, Overall: 1.89919e-03, Domain: 1.84517e-04, BC: 1.37665e-05, IC: 4.14675e-05, Data: 1.65944e-03, alpha: 9.37543e-01,
# ##TRAIN## Adam - Epoch: 15500, Overall: 1.86845e-03, Domain: 1.52679e-04, BC: 1.21806e-05, IC: 4.70040e-05, Data: 1.65659e-03, alpha: 9.38399e-01,
# ##TRAIN## Adam - Epoch: 15600, Overall: 3.18714e-03, Domain: 1.40390e-03, BC: 1.30299e-05, IC: 9.11680e-05, Data: 1.67905e-03, alpha: 9.25529e-01,
# ##TRAIN## Adam - Epoch: 15700, Overall: 1.69698e-02, Domain: 1.48718e-02, BC: 3.68632e-05, IC: 3.71500e-04, Data: 1.68964e-03, alpha: 9.39120e-01,
# ##TRAIN## Adam - Epoch: 15800, Overall: 1.83074e-03, Domain: 1.44931e-04, BC: 1.22580e-05, IC: 3.36292e-05, Data: 1.63992e-03, alpha: 9.45593e-01,
# ##TRAIN## Adam - Epoch: 15900, Overall: 2.28431e-03, Domain: 5.05381e-04, BC: 9.58299e-06, IC: 7.20245e-05, Data: 1.69732e-03, alpha: 9.22245e-01,
# ##TRAIN## Adam - Epoch: 16000, Overall: 3.51865e-03, Domain: 1.66302e-03, BC: 2.30097e-05, IC: 1.53217e-04, Data: 1.67940e-03, alpha: 9.31235e-01,
# ##TRAIN## Adam - Epoch: 16100, Overall: 1.82635e-03, Domain: 1.41262e-04, BC: 1.19825e-05, IC: 3.29542e-05, Data: 1.64015e-03, alpha: 9.45424e-01,
# ##TRAIN## Adam - Epoch: 16200, Overall: 2.52656e-03, Domain: 6.90234e-04, BC: 1.29450e-05, IC: 1.27835e-04, Data: 1.69554e-03, alpha: 9.23177e-01,
# ##TRAIN## Adam - Epoch: 16300, Overall: 1.83853e-03, Domain: 1.42231e-04, BC: 1.11831e-05, IC: 3.62540e-05, Data: 1.64886e-03, alpha: 9.41685e-01,
# ##TRAIN## Adam - Epoch: 16400, Overall: 2.75534e-03, Domain: 8.84582e-04, BC: 3.21556e-05, IC: 1.79209e-04, Data: 1.65939e-03, alpha: 9.35806e-01,
# ##TRAIN## Adam - Epoch: 16500, Overall: 1.82392e-03, Domain: 1.35988e-04, BC: 1.13469e-05, IC: 3.38669e-05, Data: 1.64272e-03, alpha: 9.44130e-01,
# ##TRAIN## Adam - Epoch: 16600, Overall: 1.97661e-03, Domain: 2.62014e-04, BC: 9.15681e-06, IC: 4.72718e-05, Data: 1.65817e-03, alpha: 9.37227e-01,
# ##TRAIN## Adam - Epoch: 16700, Overall: 7.14331e-03, Domain: 5.25748e-03, BC: 1.37130e-05, IC: 1.55440e-04, Data: 1.71667e-03, alpha: 9.21338e-01,
# ##TRAIN## Adam - Epoch: 16800, Overall: 2.91506e-03, Domain: 1.08497e-03, BC: 1.38517e-05, IC: 1.47842e-04, Data: 1.66839e-03, alpha: 9.33294e-01,
# ##TRAIN## Adam - Epoch: 16900, Overall: 2.91997e-02, Domain: 2.74022e-02, BC: 8.76234e-06, IC: 9.62421e-05, Data: 1.69258e-03, alpha: 9.38831e-01,
# ##TRAIN## Adam - Epoch: 17000, Overall: 1.83629e-03, Domain: 1.37137e-04, BC: 9.45775e-06, IC: 3.93579e-05, Data: 1.65034e-03, alpha: 9.40687e-01,
# ##TRAIN## Adam - Epoch: 17100, Overall: 4.11779e-03, Domain: 2.29299e-03, BC: 1.29452e-05, IC: 1.15743e-04, Data: 1.69611e-03, alpha: 9.27113e-01,
# ##TRAIN## Adam - Epoch: 17200, Overall: 6.55413e-03, Domain: 4.68920e-03, BC: 1.54083e-05, IC: 1.88081e-04, Data: 1.66144e-03, alpha: 9.36320e-01,
# ##TRAIN## Adam - Epoch: 17300, Overall: 1.01418e-02, Domain: 8.45589e-03, BC: 1.81704e-05, IC: 4.15173e-05, Data: 1.62626e-03, alpha: 9.42642e-01,
# ##TRAIN## Adam - Epoch: 17400, Overall: 1.93026e-03, Domain: 2.26141e-04, BC: 9.29156e-06, IC: 4.38410e-05, Data: 1.65098e-03, alpha: 9.39005e-01,
# ##TRAIN## Adam - Epoch: 17500, Overall: 1.99351e-03, Domain: 2.66066e-04, BC: 6.91450e-06, IC: 5.10630e-05, Data: 1.66946e-03, alpha: 9.34041e-01,
# ##TRAIN## Adam - Epoch: 17600, Overall: 1.72945e-02, Domain: 1.56422e-02, BC: 1.96427e-05, IC: 1.38852e-05, Data: 1.61875e-03, alpha: 9.51390e-01,
# ##TRAIN## Adam - Epoch: 17700, Overall: 3.90416e-02, Domain: 3.71179e-02, BC: 1.13852e-05, IC: 1.54106e-04, Data: 1.75817e-03, alpha: 9.21972e-01,
# ##TRAIN## Adam - Epoch: 17800, Overall: 1.84310e-03, Domain: 1.48778e-04, BC: 9.99450e-06, IC: 3.61400e-05, Data: 1.64819e-03, alpha: 9.41066e-01,
# ##TRAIN## Adam - Epoch: 17900, Overall: 1.83677e-03, Domain: 1.40850e-04, BC: 8.52591e-06, IC: 3.86153e-05, Data: 1.64878e-03, alpha: 9.41081e-01,
# ##TRAIN## Adam - Epoch: 18000, Overall: 5.23237e-03, Domain: 3.42691e-03, BC: 1.88097e-05, IC: 1.31296e-04, Data: 1.65535e-03, alpha: 9.28706e-01,
# ##TRAIN## Adam - Epoch: 18100, Overall: 2.90680e-03, Domain: 1.20082e-03, BC: 8.23288e-06, IC: 4.21735e-05, Data: 1.65558e-03, alpha: 9.40909e-01,
# ##TRAIN## Adam - Epoch: 18200, Overall: 1.86574e-03, Domain: 1.30499e-04, BC: 8.09837e-06, IC: 5.02772e-05, Data: 1.67686e-03, alpha: 9.30814e-01,
# ##TRAIN## Adam - Epoch: 18300, Overall: 1.80456e-03, Domain: 1.31672e-04, BC: 9.77448e-06, IC: 3.00557e-05, Data: 1.63306e-03, alpha: 9.47800e-01,
# ##TRAIN## Adam - Epoch: 18400, Overall: 1.90874e-03, Domain: 1.32781e-04, BC: 9.02004e-06, IC: 6.01711e-05, Data: 1.70676e-03, alpha: 9.21791e-01,
# ##TRAIN## Adam - Epoch: 18500, Overall: 2.51050e-03, Domain: 6.26257e-04, BC: 3.71332e-05, IC: 1.93994e-04, Data: 1.65312e-03, alpha: 9.35419e-01,
# ##TRAIN## Adam - Epoch: 18600, Overall: 1.80190e-03, Domain: 1.19532e-04, BC: 9.63743e-06, IC: 3.27642e-05, Data: 1.63996e-03, alpha: 9.44563e-01,
# ##TRAIN## Adam - Epoch: 18700, Overall: 3.59611e-03, Domain: 1.68932e-03, BC: 2.50499e-05, IC: 2.09521e-04, Data: 1.67222e-03, alpha: 9.25113e-01,
# ##TRAIN## Adam - Epoch: 18800, Overall: 1.81778e-03, Domain: 1.19288e-04, BC: 9.34484e-06, IC: 3.74456e-05, Data: 1.65170e-03, alpha: 9.39685e-01,
# ##TRAIN## Adam - Epoch: 18900, Overall: 4.15830e-03, Domain: 2.24391e-03, BC: 4.58176e-05, IC: 1.97771e-04, Data: 1.67081e-03, alpha: 9.25197e-01,
# ##TRAIN## Adam - Epoch: 19000, Overall: 1.81760e-03, Domain: 1.14568e-04, BC: 9.45788e-06, IC: 3.81648e-05, Data: 1.65541e-03, alpha: 9.38585e-01,
# ##TRAIN## Adam - Epoch: 19100, Overall: 4.96294e-03, Domain: 2.79280e-03, BC: 6.17130e-05, IC: 4.27162e-04, Data: 1.68126e-03, alpha: 9.29836e-01,
# ##TRAIN## Adam - Epoch: 19200, Overall: 1.81841e-03, Domain: 1.13667e-04, BC: 9.36851e-06, IC: 3.94797e-05, Data: 1.65589e-03, alpha: 9.38065e-01,
# ##TRAIN## Adam - Epoch: 19300, Overall: 3.12772e-03, Domain: 1.33901e-03, BC: 6.98018e-06, IC: 1.11139e-04, Data: 1.67059e-03, alpha: 9.32473e-01,
# ##TRAIN## Adam - Epoch: 19400, Overall: 1.78535e-03, Domain: 1.14592e-04, BC: 9.37741e-06, IC: 2.91943e-05, Data: 1.63219e-03, alpha: 9.47825e-01,
# ##TRAIN## Adam - Epoch: 19500, Overall: 2.07175e-03, Domain: 3.22865e-04, BC: 8.08345e-06, IC: 5.43124e-05, Data: 1.68649e-03, alpha: 9.26203e-01,
# ##TRAIN## Adam - Epoch: 19600, Overall: 1.92370e-03, Domain: 2.13456e-04, BC: 7.44114e-06, IC: 4.18666e-05, Data: 1.66094e-03, alpha: 9.37047e-01,
# ##TRAIN## Adam - Epoch: 19700, Overall: 1.92491e-03, Domain: 1.78043e-04, BC: 9.74369e-06, IC: 9.63218e-05, Data: 1.64080e-03, alpha: 9.40133e-01,
# ##TRAIN## Adam - Epoch: 19800, Overall: 3.85497e-02, Domain: 3.67191e-02, BC: 4.63047e-05, IC: 1.00983e-04, Data: 1.68335e-03, alpha: 9.40714e-01,
# ##TRAIN## Adam - Epoch: 19900, Overall: 3.28324e-03, Domain: 1.24185e-03, BC: 6.05058e-05, IC: 3.18337e-04, Data: 1.66255e-03, alpha: 9.34890e-01,
#
# Training Time:  217 [s]

# %%
plt.loglog(alpha_fun(torch.tensor(alpha_values)).cpu().detach().numpy())
plt.plot([0, epochs], [alpha_nd, alpha_nd])
plt.xlabel('Epoch')
plt.ylabel('alpha')
plt.legend(['alpha_inv', 'alpha_nd (true)'])
plt.show()

# %% [markdown]
# ## Loss functions

# %%
# Evolution of the loss function
loss_train_list = [loss_train, loss_train_dom, loss_train_bc, loss_train_ic]
colors = ['black', 'red', 'blue', 'green']
titles = ['Overall Loss', 'PDE Loss', 'BC Loss', 'IC Loss']
if isData:
    loss_train_list.append(loss_train_data)
    colors.append('magenta')
    titles.append('Data Loss')

fig, ax = plt.subplots(1, len(loss_train_list), figsize=(20, 3))
for i in range(len(loss_train_list)):
    epochs_train = np.arange(0, len(loss_train_list[i]))
    ax[i].semilogy(epochs_train, loss_train_list[i], color=colors[i], label='Train')
    ax[i].set_xlabel('Epoch')
    ax[i].set_title(titles[i])
    ax[i].legend()
plt.show()

# %% [markdown]
# ## Prediction

# %%
# Definition of tensors from the testing points for evaluating the trained PINN
pt_x = torch.from_numpy(x_test).float()
pt_t = torch.from_numpy(t_test).float()
ms_Tex = T_ref*T_exact(x_test, t_test).reshape(ms_x.shape)

# %%
# Predicted solution
X_pred = torch.cat([pt_x, pt_t], axis=1).to(device)
Tpred = model(X_pred).data.cpu().numpy()
ms_Tpred = T_ref*Tpred.reshape(ms_x.shape)

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

ax = axs[0]
h = ax.imshow(ms_Tpred.T, interpolation='nearest', cmap='jet',
              extent=[ti, tf/alpha_true, xi, xf],
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax, shrink=0.5, aspect=10)
ax.set_xlabel('Time (s)')
ax.set_ylabel('Position (m)')
ax.set_title('T_hat')

ax = axs[1]
h = ax.imshow((ms_Tpred-ms_Tex).T, interpolation='nearest', cmap='jet',
              extent=[ti, tf/alpha_true, xi, xf],
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax, shrink=0.5, aspect=10)
ax.set_xlabel('Time (s)')
ax.set_ylabel('Position (m)')
ax.set_title('T_hat - T_ex')

plt.show()
